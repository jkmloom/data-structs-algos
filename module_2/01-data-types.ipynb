# %% [markdown]
# # data types in python
# depending on the nature of the data, different stratergies and storing techniques are required by a mahcine to manage them. so we have different data types in python programming language.
#
# on a high level, this is how these data types are categorized in python:
#
# ## 1. numerical data
# i. integer -> 0, 1, 2, 3, 4, ..
# ii. floating points -> 0.5, 1.2, 3.3, ..
# iii. complex numbers -> 4+5i, 7+i, ..
#
# ## 2. sequence
# i. string
# ii. list
# iii. tuple
#
# ## 3. boolean
# i. true/1
# ii. false/0
#
# ## 4. dictionary
# ## 5. set
#
# all the data types are explained in detail in later files.
